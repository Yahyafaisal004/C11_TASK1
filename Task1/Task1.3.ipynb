# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
dataframe= pd.read_csv('YFifa22.csv')
dataframe.head()
# Out:
#    sofifa_id         short_name player_positions  overall  potential  \
# 0     158023           l. messi       RW, ST, CF       93         93
# 1     188545     r. lewandowski               ST       92         92
# 2      20801  cristiano ronaldo           ST, LW       91         91
# 3     190871          neymar jr          LW, CAM       91         91
# 4     192985       k. de bruyne          CM, CAM       91         91
#
#      value_eur  wage_eur  age  height_m  potential/wage  value/wage
# 0   78000000.0  320000.0   34      1.70        0.000291  243.750000
# 1  119500000.0  270000.0   32      1.85        0.000341  442.592593
# 2   45000000.0  270000.0   36      1.87        0.000337  166.666667
# 3  129000000.0  270000.0   29      1.75        0.000337  477.777778
# 4  125500000.0  350000.0   30      1.81        0.000260  358.571429

# %%
columns= dataframe.select_dtypes(include=['number']).columns
columns
# Out:
# Index(['sofifa_id', 'overall', 'potential', 'value_eur', 'wage_eur', 'age',
#        'height_m', 'potential/wage', 'value/wage'],
#       dtype='object')

# %%
scaler=StandardScaler()
dataframe[columns]= scaler.fit_transform(dataframe[columns])
dataframe
# Out:
#        sofifa_id          short_name player_positions   overall  potential  \
# 0      -2.716263            l. messi       RW, ST, CF  3.957501   3.601780
# 1      -1.587450      r. lewandowski               ST  3.812154   3.437470
# 2      -7.791226   cristiano ronaldo           ST, LW  3.666806   3.273160
# 3      -1.501426           neymar jr          LW, CAM  3.666806   3.273160
# 4      -1.423243        k. de bruyne          CM, CAM  3.666806   3.273160
# ...          ...                 ...              ...       ...        ...
# 19234   1.127775           song defu              CDM -2.728494  -3.134932
# 19235   1.130659           c. porter               CM -2.728494  -1.984762
# 19236   1.157287            n. logue               CM -2.728494  -2.642002
# 19237   1.159506           l. rudden               ST -2.728494  -1.820452
# 19238   1.223118  e. lalchhanchhuaha              CAM -2.728494  -1.820452
#
# ...

# %%
dataframe.to_csv('scaled_processed.csv',index=False)
